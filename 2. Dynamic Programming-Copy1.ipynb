# %%
using PyCall
using PyPlot
@pyimport matplotlib.animation as anim

# First set up the figure, the axis, and the plot element we want to animate
fig = figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
global line = ax[:plot]([], [], lw=2)[1]

# initialization function: plot the background of each frame
function init()
    global line
    line[:set_data]([], [])
    return (line,None)
end

# animation function.  This is called sequentially
function animate(i)
    x = linspace(0, 2, 1000)
    y = sin(2 * pi * (x - 0.01 * i))
    global line
    line[:set_data](x, y)
    return (line,None)
end

# call the animator.  blit=True means only re-draw the parts that have changed.
myanim = anim.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20)

myanim[:save]("/Users/zahedi/Desktop/PyPlots-sinplot.mp4", extra_args=["-vcodec", "libx264", "-pix_fmt", "yuv420p"])
# Out:
# INFO: Loading help data...
# Figure(PyObject <matplotlib.figure.Figure object at 0x11016ce50>)

# %%
Pkg.add("VideoIO")
# Out:
# INFO: Cloning cache of ImageView from git://github.com/timholy/ImageView.jl.git
# INFO: Cloning cache of VideoIO from git://github.com/kmsquire/VideoIO.jl.git
# INFO: Installing ImageView v0.1.12
# INFO: Installing VideoIO v0.0.12
# INFO: Building Homebrew
# ...
# From https://github.com/Homebrew/homebrew
#    0367e7e..9881839  master     -> origin/master
# HEAD is now at 9881839 hevea: update 2.23 bottle.
# Checking out files: 100% (3504/3504), done.
# HEAD is now at 5eca198 Somehow forgot `root_url` for this bottle
# INFO: Building Images
# INFO: Building Cairo

# %%
using Images
import ImageView
import VideoIO

io = VideoIO.open("/Users/zahedi/Desktop/PyPlots-sinplot.mp4")
f = VideoIO.openvideo(io)
# Out:
# ...
# VideoReader(...)

# %%
VideoIO.playvideo(f)
# Out:
# `VideoReader{transcode}` has no method matching VideoReader{transcode}(::VideoReader{true})
# while loading In[3], in expression starting on line 1
#
#  in openvideo at /Users/zahedi/.julia/v0.3/VideoIO/src/avio.jl:482
#  in playvideo at /Users/zahedi/.julia/v0.3/VideoIO/src/avio.jl:656
